# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('StudentPerformanceFactors.csv')
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
most_common_value = df['Teacher_Quality'].mode()[0]

# Fill the null values in the 'Teacher_Quality' column with the most common value
df['Teacher_Quality'] = df['Teacher_Quality'].fillna(most_common_value)

# Verify the changes
print(df['Teacher_Quality'])
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
#          ...
# 6602    Medium
# 6603      High
# 6604    Medium
# 6605    Medium
# 6606    Medium
# Name: Teacher_Quality, Length: 6607, dtype: object

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality                0
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
most_common_value = df['Parental_Education_Level'].mode()[0]

# Fill the null values in the 'Teacher_Quality' column with the most common value
df['Parental_Education_Level'] = df['Parental_Education_Level'].fillna(most_common_value)

# Verify the changes
print(df['Parental_Education_Level'])
# Out:
# 0        High School
# 1            College
# 2       Postgraduate
# 3        High School
# 4            College
#             ...
# 6602     High School
# 6603     High School
# 6604    Postgraduate
# 6605     High School
# 6606    Postgraduate
# Name: Parental_Education_Level, Length: 6607, dtype: object

# %%
most_common_value = df['Distance_from_Home'].mode()[0]

# Fill the null values in the 'Teacher_Quality' column with the most common value
df['Distance_from_Home'] = df['Parental_Education_Level'].fillna(most_common_value)

# Verify the changes
print(df['Distance_from_Home'])
# Out:
# 0        High School
# 1            College
# 2       Postgraduate
# 3        High School
# 4            College
#             ...
# 6602     High School
# 6603     High School
# 6604    Postgraduate
# 6605     High School
# 6606    Postgraduate
# Name: Distance_from_Home, Length: 6607, dtype: object

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
Exam_Score_full = df[df['Exam_Score'] == 100]['Exam_Score'].count()
Previous_Scores_full = df[df['Previous_Scores'] == 100]['Previous_Scores'].count()

print(f'Number of students with full marks in Exam: {Exam_Score_full}')
print(f'Number of students with full marks in Previous Scores: {Previous_Scores_full}')
# Out:
# Number of students with full marks in Exam: 1
# Number of students with full marks in Previous Scores: 69

# %%
pass_grade = 50

df['Pass_Exam'] = 'yes'
filt = (df['Exam_Score'] < pass_grade)
df.loc[filt,'Pass_Exam'] = 'no'
df[['Exam_Score', 'Pass_Exam']].head()

df['Pass_Previous_Exam'] = 'yes'
filt = (df['Previous_Scores'] < pass_grade)
df.loc[filt,'Pass_Previous_Exam'] = 'no'
df[['Previous_Scores', 'Pass_Previous_Exam']].head()

df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['hours_studied', 'attendance', 'parental_involvement',
#        'access_to_resources', 'extracurricular_activities', 'sleep_hours',
#        'previous_scores', 'motivation_level', 'internet_access',
#        'tutoring_sessions', 'family_income', 'teacher_quality', 'school_type',
#        'peer_influence', 'physical_activity', 'learning_disabilities',
#        'parental_education_level', 'distance_from_home', 'gender',
#        'exam_score', 'pass_exam', 'pass_previous_exam'],
#       dtype='object')

# %%
value_count = df['pass_exam'].value_counts()['yes']
value_count = df['pass_previous_exam'].value_counts()['yes']

print(f"The value appears {value_count} times in the column.")
print(f"The value appears {value_count} times in the column.")
# Out:
# The value appears 6607 times in the column.
# The value appears 6607 times in the column.

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 4))

#ax
sns.histplot(x = 'exam_score', data = df, ax = ax[0], color = '#225ea8')
sns.histplot(x = 'previous_scores', data = df, ax = ax[1], color = '#225ea8')

exam_mean = df['exam_score'].mean()
previous_exam_mean = df['previous_scores'].mean()


print(f'Average score in exam : { exam_mean }\nAverage score in previous exam : { previous_exam_mean }')
plt.show()
# Out:
# Average score in exam : 67.23565914938702
# Average score in previous exam : 75.07053125472983

# %%
sns.lmplot(x='exam_score', y='previous_scores', data=df, ci=None, height=5, aspect=1.5)

# Add labels and title
plt.title("Linear Regression: exam_score vs previous_scores")
plt.xlabel("exam_score")
plt.ylabel("previous_scores")

# Show the plot
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 10)
plt.rcParams['font.size'] = 23

plt.subplot(2, 3, 1)
size = df['gender'].value_counts()
#print(size)
labels = 'Female', 'Male'
color = ['red','green']

plt.pie(size, colors = color, labels = labels, autopct = '%.2f%%')
plt.title('gender', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'gender')

# %%
count_male_exam = df[(df['exam_score'] > 75) & (df['gender'] == 'Male')].shape[0]
count_female_exam = df[(df['exam_score'] > 75) & (df['gender'] == 'Female')].shape[0]
count_male_previous_exam = df[(df['previous_scores'] > 75) & (df['gender'] == 'Male')].shape[0]
count_female_previous_exam = df[(df['previous_scores'] > 75) & (df['gender'] == 'Female')].shape[0]

print(f"The number of values where 'exam_score' > 75 and 'gender' is 'Male' is: {count_male_exam}")
print(f"The number of values where 'exam_score' > 75 and 'gender' is 'Female' is: {count_female_exam}")
print(f"The number of values where 'exam_score' > 75 and 'gender' is 'Male' is: {count_male_previous_exam}")
print(f"The number of values where 'exam_score' > 75 and 'gender' is 'Female' is: {count_female_previous_exam}")
# Out:
# The number of values where 'exam_score' > 75 and 'gender' is 'Male' is: 40
# The number of values where 'exam_score' > 75 and 'gender' is 'Female' is: 36
# The number of values where 'exam_score' > 75 and 'gender' is 'Male' is: 1867
# The number of values where 'exam_score' > 75 and 'gender' is 'Female' is: 1368

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Comparing Male & Female scores:', fontsize=20) 
# Exam score
sns.boxplot(x='gender', y='exam_score', data=df, ax=ax1)
ax1.title.set_text('exam_score vs Gender')
# previous Exam Score 
sns.boxplot(x='gender', y='previous_scores', data=df, ax=ax2)
ax2.title.set_text('previous_scores vs Gender')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Comparing Parents education vs scores:', fontsize=15)

# Math
sns.boxplot(x='parental_education_level', y='exam_score', data=df, ax=ax1)
ax1.title.set_text('exam_score vs Parents education')
var1 = ax1.set_xticklabels(ax1.get_xticklabels(), rotation=30)

# Reading
sns.boxplot(x='parental_education_level', y='previous_scores', data=df, ax=ax2)
ax2.title.set_text('previous_scores vs Parents education')
var2 = ax2.set_xticklabels(ax2.get_xticklabels(), rotation=30)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_31120\2391163086.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   var1 = ax1.set_xticklabels(ax1.get_xticklabels(), rotation=30)
# C:\Users\user\AppData\Local\Temp\ipykernel_31120\2391163086.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   var2 = ax2.set_xticklabels(ax2.get_xticklabels(), rotation=30)

# %%
from sklearn.linear_model import LinearRegression

# %%
# Prepare the data
X = df['hours_studied'].values.reshape(-1, 1) # Independent variable (hours studied)
y = df['pass_exam'].values  # Dependent variable (pass exam)

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict values
y_pred = model.predict(X)

# Visualize the data and the regression line
plt.scatter(df['hours_studied'], df['pass_exam'], color='blue', label='Data points')  # Scatter plot of original data
plt.plot(df['hours_studied'], y_pred, color='red', label='Regression line')  # Fitted regression line

# Add labels and title
plt.title("Linear Regression: Hours Studied vs Pass Exam")
plt.xlabel("Hours Studied")
plt.ylabel("Pass Exam (0=Fail, 1=Pass)")

# Show the plot
plt.legend()
plt.show()

# Print the regression coefficients
print(f"Regression Coefficient (Slope): {model.coef_[0]}")
print(f"Intercept: {model.intercept_}")
# Out:
# Regression Coefficient (Slope): 0.06752873563218391
# Intercept: 0.051724137931034475

# %%
df = pd.read_csv('StudentPerformanceFactors.csv')
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()

# %%
df.isnull().sum()
# Out:
# hours_studied                  0
# attendance                     0
# parental_involvement           0
# access_to_resources            0
# extracurricular_activities     0
# sleep_hours                    0
# previous_scores                0
# motivation_level               0
# internet_access                0
# tutoring_sessions              0
# family_income                  0
# teacher_quality               78
# school_type                    0
# peer_influence                 0
# physical_activity              0
# learning_disabilities          0
# parental_education_level      90
# distance_from_home            67
# gender                         0
# exam_score                     0
# dtype: int64

# %%
most_common_value = df['distance_from_home'].mode()[0]

# Fill the null values in the 'Teacher_Quality' column with the most common value
df['distance_from_home'] = df['distance_from_home'].fillna(most_common_value)

# Verify the changes
print(df['distance_from_home'])
# Out:
# 0           Near
# 1       Moderate
# 2           Near
# 3       Moderate
# 4           Near
#           ...
# 6602        Near
# 6603        Near
# 6604        Near
# 6605         Far
# 6606        Near
# Name: distance_from_home, Length: 6607, dtype: object

# %%
most_common_value = df['parental_education_level'].mode()[0]

# Fill the null values in the 'Teacher_Quality' column with the most common value
df['parental_education_level'] = df['parental_education_level'].fillna(most_common_value)

# Verify the changes
print(df['parental_education_level'])
# Out:
# 0        High School
# 1            College
# 2       Postgraduate
# 3        High School
# 4            College
#             ...
# 6602     High School
# 6603     High School
# 6604    Postgraduate
# 6605     High School
# 6606    Postgraduate
# Name: parental_education_level, Length: 6607, dtype: object

# %%
most_common_value = df['teacher_quality'].mode()[0]

# Fill the null values in the 'Teacher_Quality' column with the most common value
df['teacher_quality'] = df['teacher_quality'].fillna(most_common_value)

# Verify the changes
print(df['teacher_quality'])
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
#          ...
# 6602    Medium
# 6603      High
# 6604    Medium
# 6605    Medium
# 6606    Medium
# Name: teacher_quality, Length: 6607, dtype: object

# %%
df.isnull().sum()
# Out:
# hours_studied                  0
# attendance                     0
# parental_involvement           0
# access_to_resources            0
# extracurricular_activities     0
# sleep_hours                    0
# previous_scores                0
# motivation_level               0
# internet_access                0
# tutoring_sessions              0
# family_income                  0
# teacher_quality                0
# school_type                    0
# peer_influence                 0
# physical_activity              0
# learning_disabilities          0
# parental_education_level      90
# distance_from_home             0
# gender                         0
# exam_score                     0
# dtype: int64

# %%
df.describe()
# Out:
#        hours_studied   attendance  sleep_hours  previous_scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        tutoring_sessions  physical_activity   exam_score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
# Convert columns to numeric if needed
df['exam_score'] = pd.to_numeric(df['exam_score'], errors='coerce')
df['hours_studied'] = pd.to_numeric(df['hours_studied'], errors='coerce')
df['attendance'] = pd.to_numeric(df['attendance'], errors='coerce')
df['tutoring_sessions'] = pd.to_numeric(df['tutoring_sessions'], errors='coerce')

# %%
x = df[['hours_studied', 'attendance','tutoring_sessions']]
y = df['exam_score']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=15)

# %%
print(x_train.shape)
# Out:
# (5285, 3)

# %%
print(x_test.shape)
# Out:
# (1322, 3)

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()

# %%
LR.fit(x_train.values,y_train)
# Out:
# LinearRegression()

# %%
LR.intercept_
# Out:
# 44.87582917524185

# %%
LR.coef_
# Out:
# array([0.29310576, 0.19730816, 0.49135524])

# %%
print("The LR model is: Y = ",LR.intercept_, "+", LR.coef_[0], "hours_studied + ", LR.coef_[1], "attendance+ ", LR.coef_[2], "tutoring_sessions")
# Out:
# The LR model is: Y =  44.87582917524185 + 0.2931057608793323 hours_studied +  0.1973081626541124 attendance+  0.49135523529239816 tutoring_sessions

# %%
student_score = [[30, 70, 5]]

pred = LR.predict(student_score)
print("prediction= ", pred[0])
# Out:
# prediction=  69.93734956387168

# %%
y_pred = LR.predict(x_test.values)
y_pred
# Out:
# array([66.82235744, 67.62489865, 69.17385781, ..., 71.62686874,
#        66.69510598, 68.6758483 ])

# %%
sns.regplot(x = y_test, y = y_pred, color='green')
# Out:
# <Axes: xlabel='exam_score'>

# %%
from sklearn import metrics
import numpy as np

mae = metrics.mean_absolute_error(y_test,y_pred)
mse = metrics.mean_squared_error(y_test,y_pred)
rmse = np.sqrt(metrics.mean_squared_error(y_test,y_pred))

# %%
print('mae =',mae.round(2))
print('mse =',mse.round(2))
print('rmse =',rmse.round(2))
# Out:
# mae = 1.32
# mse = 3.82
# rmse = 1.95
